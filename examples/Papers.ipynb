# %% [markdown]
# # Papers: retrieve paper metadata

# %%
from scite import papers

# %%
papers.get_paper(doi="10.1093/oxfordhb/9780199646135.013.7")
# Out:
# 2021-03-04 23:41:38,431 - Papers - Calling https://api.scite.ai/papers/10.1093/oxfordhb/9780199646135.013.7
# {'doi': '10.1093/oxfordhb/9780199646135.013.7',
#  'slug': 'mancur-olson-Q8GYxV',
#  'type': 'book',
#  'title': 'Mancur Olson,',
# ...

# %%
DOIs = ["10.1017/CBO9780511628283.008", "10.1093/oxfordhb/9780199646135.013.7"]
papers.get_papers(DOIs)
# Out:
# 2021-03-04 23:42:59,638 - Papers - Calling https://api.scite.ai/papers with a payload of 2 papers
# {'papers': {'10.1017/cbo9780511628283.008': {'doi': '10.1017/cbo9780511628283.008',
#    'slug': 'war-making-and-state-making-YQ9mlK',
#    'type': 'book-chapter',
#    'title': 'War Making and State Making as Organized Crime',
# ...

# %%
DOIs = ["10.1234", "10.1093/oxfordhb/9780199646135.013.7"]
papers.get_papers(DOIs)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-5-52856866f158> in <module>
#       1 DOIs = ["10.1234", "10.1093/oxfordhb/9780199646135.013.7"]
# ----> 2 papers.get_papers(DOIs)
#
# ~/github/scite-wrapper/scite/papers.py in get_papers(dois)
#      63     """
#      64     if not isinstance(dois, DOIs):
# ---> 65         items = DOIs(ids=[{"id": item} for item in dois])
#      66         dois = {item.id for item in items.ids}
#      67     logger.debug(f"Calling https://api.scite.ai/papers with a payload of {len(dois)} papers")
#
# ~/github/scite-wrapper/env/lib/python3.8/site-packages/pydantic/main.cpython-38-x86_64-linux-gnu.so in pydantic.main.BaseModel.__init__()
#
# ValidationError: 1 validation error for DOIs
# ids -> 0 -> id
# ...

# %%
papers.get_papers_by_target(target_doi="10.1017/CBO9780511628283.008")
# Out:
# 2021-03-04 23:45:52,195 - Papers - Calling https://api.scite.ai/papers/10.1017/CBO9780511628283.008
# {'papers': {'10.5117/9789089642950': {'doi': '10.5117/9789089642950',
#    'slug': 'less-pretension-more-ambition-KMj4E2',
#    'type': 'monograph',
#    'title': 'Less Pretension, More Ambition : Development Policy in Times of Globalization',
#    'authors': [{'family': 'Lieshout, van', 'given': 'Peter'},
#     {'family': 'Went', 'given': 'Robert'},
#     {'family': 'Kremer', 'given': 'Monique'}],
#    'year': 2010,
#    'publisher': 'Amsterdam University Press',
#    'retracted': False,
#    'memberId': 3180,
#    'issns': [],
#    'editorialNotices': [],
#    'journal': ''},
#   '10.21236/ada560718': {'doi': '10.21236/ada560718',
#    'slug': 'drug-trafficking-violence-and-instability-vaOW0O',
#    'type': 'report',
#    'title': 'Drug Trafficking, Violence, and Instability',
# ...
